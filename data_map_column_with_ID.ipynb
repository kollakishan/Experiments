# %%
# Import Dependencies
# %matplotlib inline

# Start Python Imports
import math, time, random, datetime

# Data Manipulation
import numpy as np
import pandas as pd

# %%
# Import train & test data 
train = pd.read_csv('/content/TwADR-L-train-all.csv', names=['ID','name'])
train
# Out:
#              ID                                               name
# 0      C0274714                                Adrenergic syndrome
# 1      C0018772                              Hearing Loss, Partial
# 2      C0041466                                      Typhoid Fever
# 3      C0684249                                  Carcinoma of lung
# 4      C0032961                                          Pregnancy
# 5      C0947912                                        Myasthenias
# 6      C0003578                                              Apnea
# 7      C1328504                 Hormone-refractory prostate cancer
# 8      C0332601                                  Cushingoid facies
# 9      C0027726                                 Nephrotic Syndrome
# 10     C0600125                  Electrocardiogram PR prolongation
# 11     C0027720                                          Nephrosis
# 12     C0043352                                         Xerostomia
# ...

# %%
df1 = [ ]

# %%
train
# Out:
#              ID                                               name
# 0      C0274714                                Adrenergic syndrome
# 1      C0018772                              Hearing Loss, Partial
# 2      C0041466                                      Typhoid Fever
# 3      C0684249                                  Carcinoma of lung
# 4      C0032961                                          Pregnancy
# 5      C0947912                                        Myasthenias
# 6      C0003578                                              Apnea
# 7      C1328504                 Hormone-refractory prostate cancer
# 8      C0332601                                  Cushingoid facies
# 9      C0027726                                 Nephrotic Syndrome
# 10     C0600125                  Electrocardiogram PR prolongation
# 11     C0027720                                          Nephrosis
# 12     C0043352                                         Xerostomia
# ...

# %%
train.describe()
# Out:
#               ID           name
# count      48057          48057
# unique      2220           2995
# top     C0917801  Sleeplessness
# freq        1066            590

# %%
df1 = train.drop_duplicates(subset='ID')

# %%
df1
# Out:
#             ID                                      name
# 0     C0274714                       Adrenergic syndrome
# 1     C0018772                     Hearing Loss, Partial
# 2     C0041466                             Typhoid Fever
# 3     C0684249                         Carcinoma of lung
# 4     C0032961                                 Pregnancy
# 5     C0947912                               Myasthenias
# 6     C0003578                                     Apnea
# 7     C1328504        Hormone-refractory prostate cancer
# 8     C0332601                         Cushingoid facies
# 9     C0027726                        Nephrotic Syndrome
# 10    C0600125         Electrocardiogram PR prolongation
# 11    C0027720                                 Nephrosis
# 12    C0043352                                Xerostomia
# 13    C0393761                           Middle insomnia
# 14    C0236826              Expressive language disorder
# ...

# %%
df1['Map'] = np.arange(len(df1))
df1.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          ID                   name  Map
# 0  C0274714    Adrenergic syndrome    0
# 1  C0018772  Hearing Loss, Partial    1
# 2  C0041466          Typhoid Fever    2
# 3  C0684249      Carcinoma of lung    3
# 4  C0032961              Pregnancy    4

# %%
df3 = pd.merge(df1,train, on='ID')

# %%
df3.
# Out:
#              ID                 name_x   Map                 name_y
# 0      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 1      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 2      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 3      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 4      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 5      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 6      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 7      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 8      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 9      C0274714    Adrenergic syndrome     0    Adrenergic syndrome
# 10     C0018772  Hearing Loss, Partial     1  Hearing Loss, Partial
# 11     C0018772  Hearing Loss, Partial     1  Hearing Loss, Partial
# 12     C0018772  Hearing Loss, Partial     1  Hearing Loss, Partial
# ...

# %%
del df3['name_y']

# %%
df3
# Out:
#              ID                 name_x   Map
# 0      C0274714    Adrenergic syndrome     0
# 1      C0274714    Adrenergic syndrome     0
# 2      C0274714    Adrenergic syndrome     0
# 3      C0274714    Adrenergic syndrome     0
# 4      C0274714    Adrenergic syndrome     0
# 5      C0274714    Adrenergic syndrome     0
# 6      C0274714    Adrenergic syndrome     0
# 7      C0274714    Adrenergic syndrome     0
# 8      C0274714    Adrenergic syndrome     0
# 9      C0274714    Adrenergic syndrome     0
# 10     C0018772  Hearing Loss, Partial     1
# 11     C0018772  Hearing Loss, Partial     1
# 12     C0018772  Hearing Loss, Partial     1
# 13     C0018772  Hearing Loss, Partial     1
# 14     C0018772  Hearing Loss, Partial     1
# 15     C0018772  Hearing Loss, Partial     1
# 16     C0018772  Hearing Loss, Partial     1
# 17     C0018772  Hearing Loss, Partial     1
# 18     C0018772  Hearing Loss, Partial     1
# 19     C0018772  Hearing Loss, Partial     1
# ...

# %%
df3 = df3[['Map','name_x','ID']]

# %%
df3.head(50)
# Out:
#     Map                 name_x        ID
# 0     0    Adrenergic syndrome  C0274714
# 1     0    Adrenergic syndrome  C0274714
# 2     0    Adrenergic syndrome  C0274714
# 3     0    Adrenergic syndrome  C0274714
# 4     0    Adrenergic syndrome  C0274714
# 5     0    Adrenergic syndrome  C0274714
# 6     0    Adrenergic syndrome  C0274714
# 7     0    Adrenergic syndrome  C0274714
# 8     0    Adrenergic syndrome  C0274714
# 9     0    Adrenergic syndrome  C0274714
# 10    1  Hearing Loss, Partial  C0018772
# 11    1  Hearing Loss, Partial  C0018772
# 12    1  Hearing Loss, Partial  C0018772
# 13    1  Hearing Loss, Partial  C0018772
# 14    1  Hearing Loss, Partial  C0018772
# 15    1  Hearing Loss, Partial  C0018772
# 16    1  Hearing Loss, Partial  C0018772
# 17    1  Hearing Loss, Partial  C0018772
# 18    1  Hearing Loss, Partial  C0018772
# 19    1  Hearing Loss, Partial  C0018772
# 20    2          Typhoid Fever  C0041466
# 21    2          Typhoid Fever  C0041466
# ...

# %%
df4 = pd.read_csv("/content/TwADR-L_overlap_0.csv")

# %%
df4.describe()
# Out:
#         C0455769 still not tired
# count        143             143
# unique        91             133
# top     C0917801         anxiety
# freq           6               2

# %%
df3 = df3[['Map','name_x','ID']]
